# %%
#created by vipul valia Sat, March 24th, 2018

inputs = input("What would you like to search -->")
import json
from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser

DEVELOPER_KEY = "AIzaSyCIA-S7TAplu3NFjPy3kMmnaffklV7Vz2c"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
                    developerKey=DEVELOPER_KEY)

import sys
sys.path.append("C:/Users/VIPUL/OneDrive/New folder (2)/youtube_tutorial-master/youtube_tutorial-master")

def youtube_search(q, max_results=50,order="relevance", token=None, location=None, location_radius=None):

  youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)

  search_response = youtube.search().list(
    q=q,
    type="video",
    pageToken=token,
    order = order,
    part="id,snippet",
    maxResults=max_results,
    location=location,
    locationRadius=location_radius

  ).execute()
    
  videos = []

  for search_result in search_response.get("items", []):
    if search_result["id"]["kind"] == "youtube#video":
      videos.append(search_result)
  try:
      nexttok = search_response["nextPageToken"]
      return(nexttok, videos)
  except Exception as e:
      nexttok = "last_page"
      return(nexttok, videos)
    
video_dict = {'youID':[]}

def grab_videos(keyword, token=None):
    res = youtube_search(keyword, token=token)
    token = res[0]
    videos = res[1]
    for vid in videos:
        video_dict['youID'].append(vid['id']['videoId'])
    print("added " + str(len(videos)) + " videos to a total of " + str(len(video_dict['youID'])))
    return token
    
def get_likes(video_id):
    video_list_response = youtube.videos().list(id=video_id, part='id,snippet,statistics').execute()
    return video_list_response
    

token = grab_videos(inputs)
while token != "last_page":
    token = grab_videos(inputs, token=token)
    
maxs = str(len(video_dict['youID']))
def check(inp,maxs):
    if inp > maxs:
        return False
    elif inp < 1:
        return False
    else:
        return True
    
var_check = False
input2 = 0
while var_check != True:
    input2 = int(input("How many rows do you need? It should be less than %s and greater than 0 --> " % maxs))
    var_check = check(input2,int(maxs))
    

res = []
counter = 0
for ids in video_dict['youID']:
    if counter == int(input2):
        break
    abcd = get_likes(ids)
    for i in abcd['items']:
        temp = dict(v_id = i['id'])
        temp.update(i['statistics'])
        temp.update(i['snippet'])
        
    res.append(temp)
    counter += 1

import pandas as pd
a = pd.DataFrame.from_dict(res)
a

maxlikes = a['likeCount'].fillna("").max()
titlemaxlikes =  a[a['likeCount'] == maxlikes]['title']
maxviews = a['viewCount'].fillna("").max()

titlemaxviews = a[a['viewCount'] == maxviews]['title']
print("\n")
print(titlemaxlikes.to_string() + " has the maximum Likes")
print(titlemaxviews.to_string() + " has the maximum Views")
# Out:
# What would you like to search -->kenny sebastian
# added 50 videos to a total of 50
# added 50 videos to a total of 100
# added 50 videos to a total of 150
# added 50 videos to a total of 200
# added 50 videos to a total of 250
# added 50 videos to a total of 300
# added 50 videos to a total of 350
# added 50 videos to a total of 400
# added 50 videos to a total of 450
# added 50 videos to a total of 500
# added 4 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# added 0 videos to a total of 504
# How many rows do you need? It should be less than 504 and greater than 0 --> 500
#
#
# 120    3 South Indian Boys in Space | STAR BOYZ | KEB... has the maximum likes
# ...
